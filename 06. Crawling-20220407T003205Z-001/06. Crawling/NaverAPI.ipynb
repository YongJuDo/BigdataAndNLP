# %%
import pandas as pd
import os
import sys
import urllib.request
import json
import re

# %%
def clean_html(x):
  #https://predictor-ver1.tistory.com/4
  x = re.sub("\&\w*\;","",x)
  x = re.sub("<.*?>","",x)
  return x

# %%
client_id = "oxJCAm4bQizDLUER7pR4" #발급받은 ID 입력
client_secret = "aTWLeSSLPh" #발급받은 PW 입력
encText = urllib.parse.quote("리니지") # 검색할 단어 입력
url = "https://openapi.naver.com/v1/search/news?query=" + encText # json 결과
#url = "https://openapi.naver.com/v1/search/news.xml?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    result = response_body.decode('utf-8')
    #print(result)
else:
    print("Error Code:" + rescode)

# %%
result_json = json.loads(result)

# %%
df_json = pd.DataFrame(result_json["items"])

# %%
df_json
# Out:
#                                                title  \
# 0                 [이슈진단+] 주요 게임사 주총 끝...키워드는 신작-블록체인
# 1   [위클리] <b>리니지</b>W &quot;라마단 이벤트 혜택 꼭 챙겨주세요&quot;
# 2   엔씨소프트, 프로야구 개막 기념 '2022 UP' 이벤트…다양한 아이템 획득 가능...
# 3                      엔씨소프트 주주총회, 김택진 “글로벌 게임사로 도약”
# 4                   [특징주] 엔씨소프트, 글로벌 시장 리더십 강화 ‘상승세’
# 5      엔씨소프트, 제25기 정기 주주총회 개최…다양한 신작개발과 콘솔로 플랫폼 확...
# 6                           [데스크칼럼] 통섭의 리더를 떠나보내며...
# 7  게임 R&amp;D 투자, 넷마블 5600억 투입 '최고' 펄어비스 매출 대비 비중...
# 8                      GDC 2022 폐막…韓 게임사, 어떤 비전 제시했나
# 9       유동수 의원, 게임콘텐츠 이용과정에서 발생하는 소비자피해를 막기 위한 게임...
#
#                                         originallink  \
# 0        https://zdnet.co.kr/view/?no=20220331103843
# 1  http://www.gameple.co.kr/news/articleView.html...
# 2         https://www.xportsnews.com/article/1555175
# 3                https://vop.co.kr/A00001610584.html
# 4         https://www.etoday.co.kr/news/view/2119365
# 5         https://www.xportsnews.com/article/1555125
# 6          https://www.paxnetnews.com/articles/85178
# 7  http://www.consumernews.co.kr/news/articleView...
# 8   http://www.kukinews.com/newsView/kuk202203300155
# 9  http://www.weeklytrade.co.kr/news/view.html?se...
#
#                                                 link  \
# 0  https://news.naver.com/main/read.naver?mode=LS...
# 1  http://www.gameple.co.kr/news/articleView.html...
# 2  https://news.naver.com/main/read.naver?mode=LS...
# 3                https://vop.co.kr/A00001610584.html
# 4         https://www.etoday.co.kr/news/view/2119365
# 5  https://news.naver.com/main/read.naver?mode=LS...
# 6          https://www.paxnetnews.com/articles/85178
# 7  http://www.consumernews.co.kr/news/articleView...
# 8   http://www.kukinews.com/newsView/kuk202203300155
# 9  http://www.weeklytrade.co.kr/news/view.html?se...
#
#                                          description  \
# 0  <b>리니지</b>W는 올해 하반기 북미와 유럽 등 서구권 국가에 출시할 계획이다....
# 1  엔씨소프트의 대표작 '<b>리니지</b>W'가 지난 29일 '위클리 뉴스'를 통해 ...
# 2  엔씨(NC)가 서비스하는 ▲PC온라인 게임 4종(<b>리니지</b>, <b>리니지<...
# 3  엔씨소프트는 31일 주주총회를 통해 TL, <b>리니지</b>W를 비롯한 다양한 장...
# 4  출시한 <b>리니지</b>W는 다시 한번 국내 시장 1위를 만들어 놓기도 했다”고 ...
# 5  <b>리니지</b>W는 올해 하반기 북미와 유럽 등 서구권 국가에 출시할 계획이다....
# 6  친구인 송재경 대표가 개발한 '<b>리니지</b>'로 엔씨소프트가 상장을 통해 상당...
# 7  엔씨소프트는 대부분의 R&amp;D가 게임 콘텐츠 업데이트를 위해 진행됐으며 <b>...
# 8  엔씨소프트 엔씨소프트, MMORPG 속 AI 적용사례 설명 엔씨소프트는 ‘<b>리니...
# 9  실제로 지난해 NC소프트가 서비스하고 있는 ‘<b>리니지</b>M’에서 문양 시스템...
#
#                            pubDate
# 0  Thu, 31 Mar 2022 10:40:00 +0900
# 1  Thu, 31 Mar 2022 10:14:00 +0900
# 2  Thu, 31 Mar 2022 10:13:00 +0900
# 3  Thu, 31 Mar 2022 10:12:00 +0900
# 4  Thu, 31 Mar 2022 09:38:00 +0900
# 5  Thu, 31 Mar 2022 09:07:00 +0900
# 6  Thu, 31 Mar 2022 08:34:00 +0900
# 7  Thu, 31 Mar 2022 07:22:00 +0900
# 8  Thu, 31 Mar 2022 06:34:00 +0900
# 9  Thu, 31 Mar 2022 03:50:00 +0900

# %%
df_json['title'] = df_json['title'].apply(lambda x: clean_html(x))
df_json['description'] = df_json['description'].apply(lambda x: clean_html(x))

# %%
df_json
# Out:
#                                                title  \
# 0                 [이슈진단+] 주요 게임사 주총 끝...키워드는 신작-블록체인
# 1                      [위클리] 리니지W 라마단 이벤트 혜택 꼭 챙겨주세요
# 2   엔씨소프트, 프로야구 개막 기념 '2022 UP' 이벤트…다양한 아이템 획득 가능...
# 3                      엔씨소프트 주주총회, 김택진 “글로벌 게임사로 도약”
# 4                   [특징주] 엔씨소프트, 글로벌 시장 리더십 강화 ‘상승세’
# 5      엔씨소프트, 제25기 정기 주주총회 개최…다양한 신작개발과 콘솔로 플랫폼 확...
# 6                           [데스크칼럼] 통섭의 리더를 떠나보내며...
# 7  게임 RD 투자, 넷마블 5600억 투입 '최고' 펄어비스 매출 대비 비중 32% ...
# 8                      GDC 2022 폐막…韓 게임사, 어떤 비전 제시했나
# 9       유동수 의원, 게임콘텐츠 이용과정에서 발생하는 소비자피해를 막기 위한 게임...
#
#                                         originallink  \
# 0        https://zdnet.co.kr/view/?no=20220331103843
