# %%
import torch
import torch.optim as optim
import numpy as np

# %%
# Random seed to make results deterministic and reproducible
torch.manual_seed(0)

# %%
sample = " if you want you"

# %%
# make dictionary
char_set = list(set(sample))
char_dic = {c: i for i, c in enumerate(char_set)}
print(char_dic)
# Out:
# {'t': 0, 'u': 1, ' ': 2, 'f': 3, 'i': 4, 'w': 5, 'n': 6, 'o': 7, 'y': 8, 'a': 9}

# %%
# hyper parameters
dic_size = len(char_dic)
hidden_size = len(char_dic)
learning_rate = 0.1

# %%
# data setting
sample_idx = [char_dic[c] for c in sample]
x_data = [sample_idx[:-1]]
x_one_hot = [np.eye(dic_size)[x] for x in x_data]
y_data = [sample_idx[1:]]

# %%
# transform as torch tensor variable
X = torch.FloatTensor(x_one_hot)
Y = torch.LongTensor(y_data)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:210.)

# %%
# declare RNN
rnn = torch.nn.RNN(dic_size, hidden_size, batch_first=True)

# %%
# loss & optimizer setting
criterion = torch.nn.CrossEntropyLoss()
optimizer = optim.Adam(rnn.parameters(), learning_rate)

# %%
# start training
for i in range(50):
    optimizer.zero_grad()
    outputs, _status = rnn(X)
    loss = criterion(outputs.view(-1, dic_size), Y.view(-1))
    loss.backward()
    optimizer.step()

    result = outputs.data.numpy().argmax(axis=2)
    result_str = ''.join([char_set[c] for c in np.squeeze(result)])
    print(i, "loss: ", loss.item(), "prediction: ", result, "true Y: ", y_data, "prediction str: ", result_str)
# Out:
# 0 loss:  2.197417974472046 prediction:  [[8 7 7 8 8 0 8 7 7 0 5 5 8 8 0]] true Y:  [[4, 3, 2, 8, 7, 1, 2, 5, 9, 6, 0, 2, 8, 7, 1]] prediction str:  yooyytyootwwyyt
# 1 loss:  1.8724064826965332 prediction:  [[8 7 2 8 7 1 2 7 7 1 1 2 8 7 1]] true Y:  [[4, 3, 2, 8, 7, 1, 2, 5, 9, 6, 0, 2, 8, 7, 1]] prediction str:  yo you oouu you
# 2 loss:  1.6389315128326416 prediction:  [[8 7 2 8 7 1 2 5 7 6 2 2 8 7 1]] true Y:  [[4, 3, 2, 8, 7, 1, 2, 5, 9, 6, 0, 2, 8, 7, 1]] prediction str:  yo you won  you
# 3 loss:  1.4547905921936035 prediction:  [[8 7 2 8 7 1 2 5 7 6 0 2 8 7 1]] true Y:  [[4, 3, 2, 8, 7, 1, 2, 5, 9, 6, 0, 2, 8, 7, 1]] prediction str:  yo you wont you
# 4 loss:  1.3412806987762451 prediction:  [[8 3 2 8 7 1 2 5 9 6 0 2 8 7 1]] true Y:  [[4, 3, 2, 8, 7, 1, 2, 5, 9, 6, 0, 2, 8, 7, 1]] prediction str:  yf you want you
# 5 loss:  1.2337456941604614 prediction:  [[4 3 2 8 7 1 2 5 9 6 0 2 8 7 1]] true Y:  [[4, 3, 2, 8, 7, 1, 2, 5, 9, 6, 0, 2, 8, 7, 1]] prediction str:  if you want you
# 6 loss:  1.1535090208053589 prediction:  [[4 3 2 8 7 1 2 8 9 6 0 2 8 7 1]] true Y:  [[4, 3, 2, 8, 7, 1, 2, 5, 9, 6, 0, 2, 8, 7, 1]] prediction str:  if you yant you
# 7 loss:  1.0988067388534546 prediction:  [[4 3 2 8 7 1 2 8 7 6 0 2 8 7 1]] true Y:  [[4, 3, 2, 8, 7, 1, 2, 5, 9, 6, 0, 2, 8, 7, 1]] prediction str:  if you yont you
# 8 loss:  1.0413289070129395 prediction:  [[4 3 2 8 7 1 2 8 9 6 0 2 8 7 1]] true Y:  [[4, 3, 2, 8, 7, 1, 2, 5, 9, 6, 0, 2, 8, 7, 1]] prediction str:  if you yant you
# 9 loss:  1.0026638507843018 prediction:  [[4 3 2 8 7 1 2 8 9 6 0 2 8 7 1]] true Y:  [[4, 3, 2, 8, 7, 1, 2, 5, 9, 6, 0, 2, 8, 7, 1]] prediction str:  if you yant you
# 10 loss:  0.9725605845451355 prediction:  [[4 3 2 8 7 1 2 8 9 6 0 2 8 7 1]] true Y:  [[4, 3, 2, 8, 7, 1, 2, 5, 9, 6, 0, 2, 8, 7, 1]] prediction str:  if you yant you
# 11 loss:  0.94647616147995 prediction:  [[4 3 2 8 7 1 2 8 9 6 0 2 8 7 1]] true Y:  [[4, 3, 2, 8, 7, 1, 2, 5, 9, 6, 0, 2, 8, 7, 1]] prediction str:  if you yant you
# 12 loss:  0.93173748254776 prediction:  [[4 3 2 8 7 1 2 8 9 6 0 2 8 7 1]] true Y:  [[4, 3, 2, 8, 7, 1, 2, 5, 9, 6, 0, 2, 8, 7, 1]] prediction str:  if you yant you
# 13 loss:  0.916057288646698 prediction:  [[4 3 2 8 7 1 2 8 9 6 0 2 8 7 1]] true Y:  [[4, 3, 2, 8, 7, 1, 2, 5, 9, 6, 0, 2, 8, 7, 1]] prediction str:  if you yant you
# 14 loss:  0.9020840525627136 prediction:  [[4 3 2 8 7 1 2 5 9 6 0 2 8 7 1]] true Y:  [[4, 3, 2, 8, 7, 1, 2, 5, 9, 6, 0, 2, 8, 7, 1]] prediction str:  if you want you
# 15 loss:  0.8982431888580322 prediction:  [[4 3 2 8 7 1 2 5 9 6 0 2 8 7 1]] true Y:  [[4, 3, 2, 8, 7, 1, 2, 5, 9, 6, 0, 2, 8, 7, 1]] prediction str:  if you want you
# 16 loss:  0.8829825520515442 prediction:  [[4 3 2 8 7 1 2 8 9 6 0 2 8 7 1]] true Y:  [[4, 3, 2, 8, 7, 1, 2, 5, 9, 6, 0, 2, 8, 7, 1]] prediction str:  if you yant you
# 17 loss:  0.879551887512207 prediction:  [[4 3 2 8 7 1 2 8 9 6 0 2 8 7 1]] true Y:  [[4, 3, 2, 8, 7, 1, 2, 5, 9, 6, 0, 2, 8, 7, 1]] prediction str:  if you yant you
# 18 loss:  0.8720454573631287 prediction:  [[4 3 2 8 7 1 2 8 9 6 0 2 8 7 1]] true Y:  [[4, 3, 2, 8, 7, 1, 2, 5, 9, 6, 0, 2, 8, 7, 1]] prediction str:  if you yant you
# 19 loss:  0.8658919930458069 prediction:  [[4 3 2 8 7 1 2 5 9 6 0 2 8 7 1]] true Y:  [[4, 3, 2, 8, 7, 1, 2, 5, 9, 6, 0, 2, 8, 7, 1]] prediction str:  if you want you
# 20 loss:  0.8635313510894775 prediction:  [[4 3 2 8 7 1 2 5 9 6 0 2 8 7 1]] true Y:  [[4, 3, 2, 8, 7, 1, 2, 5, 9, 6, 0, 2, 8, 7, 1]] prediction str:  if you want you
# 21 loss:  0.8607019782066345 prediction:  [[4 3 2 8 7 1 2 5 9 6 0 2 8 7 1]] true Y:  [[4, 3, 2, 8, 7, 1, 2, 5, 9, 6, 0, 2, 8, 7, 1]] prediction str:  if you want you
# 22 loss:  0.8566759824752808 prediction:  [[4 3 2 8 7 1 2 5 9 6 0 2 8 7 1]] true Y:  [[4, 3, 2, 8, 7, 1, 2, 5, 9, 6, 0, 2, 8, 7, 1]] prediction str:  if you want you
# 23 loss:  0.8536787033081055 prediction:  [[4 3 2 8 7 1 2 8 9 6 0 2 8 7 1]] true Y:  [[4, 3, 2, 8, 7, 1, 2, 5, 9, 6, 0, 2, 8, 7, 1]] prediction str:  if you yant you
# 24 loss:  0.8517707586288452 prediction:  [[4 3 2 8 7 1 2 8 9 6 0 2 8 7 1]] true Y:  [[4, 3, 2, 8, 7, 1, 2, 5, 9, 6, 0, 2, 8, 7, 1]] prediction str:  if you yant you
# 25 loss:  0.848326563835144 prediction:  [[4 3 2 8 7 1 2 5 9 6 0 2 8 7 1]] true Y:  [[4, 3, 2, 8, 7, 1, 2, 5, 9, 6, 0, 2, 8, 7, 1]] prediction str:  if you want you
# 26 loss:  0.8466688990592957 prediction:  [[4 3 2 8 7 1 2 5 9 6 0 2 8 7 1]] true Y:  [[4, 3, 2, 8, 7, 1, 2, 5, 9, 6, 0, 2, 8, 7, 1]] prediction str:  if you want you
# 27 loss:  0.8454004526138306 prediction:  [[4 3 2 8 7 1 2 5 9 6 0 2 8 7 1]] true Y:  [[4, 3, 2, 8, 7, 1, 2, 5, 9, 6, 0, 2, 8, 7, 1]] prediction str:  if you want you
# 28 loss:  0.8435867428779602 prediction:  [[4 3 2 8 7 1 2 5 9 6 0 2 8 7 1]] true Y:  [[4, 3, 2, 8, 7, 1, 2, 5, 9, 6, 0, 2, 8, 7, 1]] prediction str:  if you want you
# 29 loss:  0.8422352075576782 prediction:  [[4 3 2 8 7 1 2 5 9 6 0 2 8 7 1]] true Y:  [[4, 3, 2, 8, 7, 1, 2, 5, 9, 6, 0, 2, 8, 7, 1]] prediction str:  if you want you
# 30 loss:  0.8417084813117981 prediction:  [[4 3 2 8 7 1 2 5 9 6 0 2 8 7 1]] true Y:  [[4, 3, 2, 8, 7, 1, 2, 5, 9, 6, 0, 2, 8, 7, 1]] prediction str:  if you want you
# 31 loss:  0.8405033946037292 prediction:  [[4 3 2 8 7 1 2 5 9 6 0 2 8 7 1]] true Y:  [[4, 3, 2, 8, 7, 1, 2, 5, 9, 6, 0, 2, 8, 7, 1]] prediction str:  if you want you
# 32 loss:  0.8394317626953125 prediction:  [[4 3 2 8 7 1 2 5 9 6 0 2 8 7 1]] true Y:  [[4, 3, 2, 8, 7, 1, 2, 5, 9, 6, 0, 2, 8, 7, 1]] prediction str:  if you want you
# 33 loss:  0.8388570547103882 prediction:  [[4 3 2 8 7 1 2 5 9 6 0 2 8 7 1]] true Y:  [[4, 3, 2, 8, 7, 1, 2, 5, 9, 6, 0, 2, 8, 7, 1]] prediction str:  if you want you
# 34 loss:  0.8380303978919983 prediction:  [[4 3 2 8 7 1 2 5 9 6 0 2 8 7 1]] true Y:  [[4, 3, 2, 8, 7, 1, 2, 5, 9, 6, 0, 2, 8, 7, 1]] prediction str:  if you want you
# 35 loss:  0.8369722366333008 prediction:  [[4 3 2 8 7 1 2 5 9 6 0 2 8 7 1]] true Y:  [[4, 3, 2, 8, 7, 1, 2, 5, 9, 6, 0, 2, 8, 7, 1]] prediction str:  if you want you
# 36 loss:  0.8362739086151123 prediction:  [[4 3 2 8 7 1 2 5 9 6 0 2 8 7 1]] true Y:  [[4, 3, 2, 8, 7, 1, 2, 5, 9, 6, 0, 2, 8, 7, 1]] prediction str:  if you want you
# 37 loss:  0.8356691598892212 prediction:  [[4 3 2 8 7 1 2 5 9 6 0 2 8 7 1]] true Y:  [[4, 3, 2, 8, 7, 1, 2, 5, 9, 6, 0, 2, 8, 7, 1]] prediction str:  if you want you
# 38 loss:  0.8346595168113708 prediction:  [[4 3 2 8 7 1 2 5 9 6 0 2 8 7 1]] true Y:  [[4, 3, 2, 8, 7, 1, 2, 5, 9, 6, 0, 2, 8, 7, 1]] prediction str:  if you want you
# 39 loss:  0.8337819576263428 prediction:  [[4 3 2 8 7 1 2 5 9 6 0 2 8 7 1]] true Y:  [[4, 3, 2, 8, 7, 1, 2, 5, 9, 6, 0, 2, 8, 7, 1]] prediction str:  if you want you
# 40 loss:  0.8327409029006958 prediction:  [[4 3 2 8 7 1 2 5 9 6 0 2 8 7 1]] true Y:  [[4, 3, 2, 8, 7, 1, 2, 5, 9, 6, 0, 2, 8, 7, 1]] prediction str:  if you want you
# 41 loss:  0.831129789352417 prediction:  [[4 3 2 8 7 1 2 5 9 6 0 2 8 7 1]] true Y:  [[4, 3, 2, 8, 7, 1, 2, 5, 9, 6, 0, 2, 8, 7, 1]] prediction str:  if you want you
# 42 loss:  0.8291624188423157 prediction:  [[4 3 2 8 7 1 2 5 9 6 0 2 8 7 1]] true Y:  [[4, 3, 2, 8, 7, 1, 2, 5, 9, 6, 0, 2, 8, 7, 1]] prediction str:  if you want you
# 43 loss:  0.8277190923690796 prediction:  [[4 3 2 8 7 1 2 5 9 6 0 2 8 7 1]] true Y:  [[4, 3, 2, 8, 7, 1, 2, 5, 9, 6, 0, 2, 8, 7, 1]] prediction str:  if you want you
# 44 loss:  0.8279259204864502 prediction:  [[4 3 2 8 7 1 2 5 9 6 0 2 8 7 1]] true Y:  [[4, 3, 2, 8, 7, 1, 2, 5, 9, 6, 0, 2, 8, 7, 1]] prediction str:  if you want you
# 45 loss:  0.82826828956604 prediction:  [[4 3 2 8 7 1 2 5 9 6 0 2 8 7 1]] true Y:  [[4, 3, 2, 8, 7, 1, 2, 5, 9, 6, 0, 2, 8, 7, 1]] prediction str:  if you want you
# 46 loss:  0.8270372152328491 prediction:  [[4 3 2 8 7 1 2 5 9 6 0 2 8 7 1]] true Y:  [[4, 3, 2, 8, 7, 1, 2, 5, 9, 6, 0, 2, 8, 7, 1]] prediction str:  if you want you
# 47 loss:  0.8257124423980713 prediction:  [[4 3 2 8 7 1 2 5 9 6 0 2 8 7 1]] true Y:  [[4, 3, 2, 8, 7, 1, 2, 5, 9, 6, 0, 2, 8, 7, 1]] prediction str:  if you want you
# 48 loss:  0.8248019814491272 prediction:  [[4 3 2 8 7 1 2 5 9 6 0 2 8 7 1]] true Y:  [[4, 3, 2, 8, 7, 1, 2, 5, 9, 6, 0, 2, 8, 7, 1]] prediction str:  if you want you
# 49 loss:  0.8240777254104614 prediction:  [[4 3 2 8 7 1 2 5 9 6 0 2 8 7 1]] true Y:  [[4, 3, 2, 8, 7, 1, 2, 5, 9, 6, 0, 2, 8, 7, 1]] prediction str:  if you want you
